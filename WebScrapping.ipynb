# %% [markdown]
# <a href="https://colab.research.google.com/github/Alyssonj/Python/blob/main/WebScrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import datetime
from dateutil.relativedelta import relativedelta

# %%
Site = 'http://www.ssp.sp.gov.br/Estatistica/ViolenciaMulher.aspx'
Pag = requests.get(Site)

# %%
Coleta = BeautifulSoup(Pag.text,'html.parser')
print(Coleta.title)

# %%
Tabelas = Coleta.find_all('table',attrs={'class':'table table-striped table-hover table-condensed'})
print('Localizado:',len(Tabelas),'tabelas')

# %%
Rotulos=[]
Dados=[]
Periodos=[]
Registro_Inicial=datetime.datetime(2021,9,1)
Loop = 0
for Consulta in Tabelas:
  Linha=Consulta.find_all('tr')[2]
  Rotulo=Linha.find_all('td')[0].text
  Informação=Linha.find_all('span')[0].text
  Data=Registro_Inicial-relativedelta(months=Loop)
  if Rotulo == 'FEMINICÍDIO':
    Rotulos.append(Rotulo)
    Dados.append(Informação)
    Periodos.append(Data)
  else:
    pass

Loop += 1

# %%
Dicionario = {
    'Indicador':Rotulos,
    'Quantidade':Dados,
    'Periodos':Periodos
}
BD=pd.DataFrame(Dicionario)
BD
# Out:
#       Indicador Quantidade   Periodos
# 0   FEMINICÍDIO          9 2021-09-01
# 1   FEMINICÍDIO          6 2021-09-01
# 2   FEMINICÍDIO          8 2021-09-01
# 3   FEMINICÍDIO          8 2021-09-01
# 4   FEMINICÍDIO          7 2021-09-01
# 5   FEMINICÍDIO         26 2021-09-01
# 6   FEMINICÍDIO         10 2021-09-01
# 7   FEMINICÍDIO         21 2021-09-01
# 8   FEMINICÍDIO         11 2021-09-01
# 9   FEMINICÍDIO         11 2021-09-01
# 10  FEMINICÍDIO         19 2021-09-01
# 11  FEMINICÍDIO         20 2021-09-01
# 12  FEMINICÍDIO         14 2021-09-01
# 13  FEMINICÍDIO         17 2021-09-01
# 14  FEMINICÍDIO          8 2021-09-01
# 15  FEMINICÍDIO         13 2021-09-01
# 16  FEMINICÍDIO          8 2021-09-01
# 17  FEMINICÍDIO          9 2021-09-01
# 18  FEMINICÍDIO         21 2021-09-01
# 19  FEMINICÍDIO         20 2021-09-01
# 20  FEMINICÍDIO         18 2021-09-01
# 21  FEMINICÍDIO         12 2021-09-01
# 22  FEMINICÍDIO         27 2021-09-01
# 23  FEMINICÍDIO         17 2021-09-01
# 24  FEMINICÍDIO         18 2021-09-01
# 25  FEMINICÍDIO         19 2021-09-01
# 26  FEMINICÍDIO         13 2021-09-01
# 27  FEMINICÍDIO          5 2021-09-01
# 28  FEMINICÍDIO         11 2021-09-01
# 29  FEMINICÍDIO         19 2021-09-01
# 30  FEMINICÍDIO         16 2021-09-01
# 31  FEMINICÍDIO         13 2021-09-01
# 32  FEMINICÍDIO         12 2021-09-01
# 33  FEMINICÍDIO         14 2021-09-01
# 34  FEMINICÍDIO         15 2021-09-01
# 35  FEMINICÍDIO          9 2021-09-01
# 36  FEMINICÍDIO         17 2021-09-01
# 37  FEMINICÍDIO         11 2021-09-01
# 38  FEMINICÍDIO         11 2021-09-01
# 39  FEMINICÍDIO         16 2021-09-01
# 40  FEMINICÍDIO          6 2021-09-01
# 41  FEMINICÍDIO         16 2021-09-01
# 42  FEMINICÍDIO         14 2021-09-01
# 43  FEMINICÍDIO          8 2021-09-01
# 44  FEMINICÍDIO          8 2021-09-01
# 45  FEMINICÍDIO          5 2021-09-01
